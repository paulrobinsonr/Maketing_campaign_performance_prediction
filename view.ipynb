# %%
import pandas as pd
nykaa_df=pd.read_csv('data/nykaa_campaign_data_with_nulls.csv')
purplle_df=pd.read_csv('data/purplle_campaign_data_with_nulls.csv')
tira_df=pd.read_csv('data/tira_campaign_data_with_nulls.csv')

# %%
print("Nykaa:", nykaa_df.shape)
print("Purplle:", purplle_df.shape)
print("Tira:", tira_df.shape)
# Out:
# Nykaa: (55555, 16)
# Purplle: (55555, 16)
# Tira: (55555, 16)
